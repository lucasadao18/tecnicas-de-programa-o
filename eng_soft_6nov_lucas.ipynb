# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasadao18/tecnicas-de-programa-o/blob/main/eng_soft_6nov_lucas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#QUESTAO 1
#Faça um programa que leia dois números
#inteiros e exiba a soma deles
numero_inteiro=int(input("Digite um numero inteiro:"))
numero_inteiro2=int(input("Digite um numero inteiro:"))
numero_inteiro+numero_inteiro2
# Out:
# Digite um numero inteiro:44
# Digite um numero inteiro:22
# 66

# %%
#QUESTAO 2
#Faça um programa que leia a nota que um
#aluno tirou em P1(Prova 1) e P2(Prova 2)
P1=float(input("Digite a nota da prova 1:"))
P2=float(input("Digite a nota da prova 2:"))
print("a media é: ", (P1+P2)/2)
# Out:
# Digite a nota da prova 1:40
# Digite a nota da prova 2:65
# a media é:  52.5

# %%
#TAREFA 3
'''
Leia um nome armazenado em uma variável
e imprima:
Olá, nome_pessoa!
(nome_pessoa é a variável)
TAREFA 3
Conceitos
'''
nome=input("Digite seu nome:")
print("Olá,", nome)
# Out:
# Digite seu nome:Lucas
# Olá, Lucas

# %%
'''
Solicite que o usuário digite seu nome.
Solicite que o usuários digite seu ano de nascimento (formato AAAA).
Exiba na tela:
nome_usuario nasceu em ano_nascimento!
(nome_usuario e ano_nascimento
são as variáveis)
'''
nome=input("Digite seu nome:")
ano_nascimento=int(input("Digite seu ano de nascimento:"))
print(nome, "nasceu em", ano_nascimento)
#
# Out:
# Digite seu nome:lucas

# %%
'''
Solicite que o usuário digite seu nome e sua idade.
Imprima “Olá, nome! Você tem idade anos?”
Imprima o ano de nascimento da pessoa (ignore meses e dias)
Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...
'''
nome=input("Digite seu nome:")
idade=int(input("Digite sua idade:"))
ano_nascimento=2023-idade
print("Olá,", nome, "você tem", idade, "anos")
print("Você nasceu em", ano_nascimento)
print(nome*idade)
