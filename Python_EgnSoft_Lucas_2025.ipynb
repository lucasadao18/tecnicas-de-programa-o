# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasadao18/tecnicas-de-programacao/blob/main/Python_EgnSoft_Lucas_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nome: Lucas Gonçalves da silva Adão
#
# Turma: N2 Engenharia de Software
#
# Materia: tecnicas e desenvolvimento de algoritimos
#
# ![Python.jpg](data:image/jpeg;base64,...)

# %%
print ("olá turma");
# Out:
# olá turma

# %%
#Operadores
'''

Operadores


'''
print()

# %%
#Operadores

'''
Como usar Python como calculadora. Abaixo será necessário informar um valor para a variável a.
'''
print()

a=10
y= 34
30*5+a-2
print(y)
type(y)
# Out:
# 34
# int

# %%
#divisão
#3//10 é diferente 3/10
'''
//divisão por inteiro
/ divisão
'''
3/10
# Out:
# 0.3

# %%
'''
operadores textuais
• concatenação: + (juntar, é o & do Flowgorithm, é a (vírgula) no código em python)
• repetição: * (multiplicar)
'''

faculdade="UDF"
print("Eu estudo no ", faculdade, (3*50)) #exemplo de concatenação
# Out:
# Eu estudo no  UDF 150

# %%
#Lista 1 (11/09)
'''
1. Escreva um programa que apresente na tela a frase: "Meu primeiro programa!!!"
'''
print("Meu primeiro programa!!!")
# Out:
# Meu primeiro programa!!!

# %%
'''
2. Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela
o número informado pelo usuário do programa
'''
print()
numero_inteiro=int
numero_inteiro=input("Digite um número inteiro:  ")
print("O número digitado foi: ", numero_inteiro)
# Out:
# Digite um número inteiro:  5
# O número digitado foi:  5

# %%
'''#3. Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela
#o número informado da seguinte forma: "Foi informado o valor: X
'''
numero_inteiro=int(input("Digite um número inteiro:  "))
print("Foi informado o valor: ", numero_inteiro)
# Out:
# Digite um número inteiro:  5
# Foi informado o valor:  5

# %%
'''
4. Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente na
tela os dois números informados da seguinte forma: "Voce informou os numeros X e Y"
'''
numero_inteiro1=int(input("Digite um número inteiro:  "))
numero_inteiro2=int(input("Digite um número inteiro:  "))
print("Voce informou os numeros ", numero_inteiro1, "e", numero_inteiro2)
# Out:
# Digite um número inteiro:  4
# Digite um número inteiro:  6
# Voce informou os numeros  4 e 6

# %%
'''
5. Escreva um programa que solicite ao usuário um número real e ao final apresente na tela o
número informado formatado com duas casas decimais da seguinte forma: "Voce informou
o numero X.YY"
'''
numero_real=float(input("Digite um número real:  "))
print("Voce informou o numero ", numero_real)
# Out:
# Digite um número real:  5
# Voce informou o numero  5.0

# %%
'''
6. Escreva um programa que solicite ao usuário a temperatura em graus Celsius e ao final
apresente a temperatura correspondente em graus Farenheit. F = Celsius * 1.8 + 32
'''
temperatura_celsius=float(input("Digite a temperatura em graus Celsius:  "))
temperatura_farenheit=temperatura_celsius*1.8+32
print("A temperatura em graus Farenheit é: ", temperatura_farenheit)
# Out:
# Digite a temperatura em graus Celsius:  5
# A temperatura em graus Farenheit é:  41.0

# %%
'''
7. Escreva um programa que solicite ao usuário um número inteiro e um número real e ao final
apresente na tela os dois números informados formatando com duas casas decimais
somente o número real da seguinte forma: "Voce informou os numeros N e X.YY"
'''
numero_inteiro=int(input("Digite um número inteiro:  "))
numero_real=float(input("Digite um número real:  "))
print("Voce informou os numeros ", numero_inteiro, "e", numero_real)
# Out:
# Digite um número inteiro:  5
# Digite um número real:  5
# Voce informou os numeros  5 e 5.0

# %%
'''
8. Escreva um programa que solicite ao usuário a primeira letra de seu nome e ao final
apresente na tela a letra informada pelo usuário da seguinte forma: "Voce digitou w"
'''
letra=input("Digite a primeira letra de seu nome:  ")
print("Voce digitou ", letra)
# Out:
# Digite a primeira letra de seu nome:  5
# Voce digitou  5

# %%
'''
9. Escreva um programa que solicite ao usuário o nome de sua cor preferida e ao final
apresente na tela a cor informada pelo usuário da seguinte forma: "Voce gosta da cor AAA"
'''
cor=input("Digite o nome de sua cor preferida:  ")
print("Voce gosta da cor ", cor)
# Out:
# Digite o nome de sua cor preferida:  5
# Voce gosta da cor  5

# %%
'''
10. Escreva um programa que solicite ao usuário o nome de uma verdura e uma fruta de sua
preferencia e ao final apresente na tela as informações digitadas pelo usuário da seguinte
forma: "Voce gosta de AAAAAAA e BBBBBBB"
'''
verdura=input("Digite o nome de uma verdura:  ")
fruta=input("Digite o nome de uma fruta:  ")
print("Voce gosta de ", verdura, "e", fruta)
# Out:
# Digite o nome de uma verdura:  alface
# Digite o nome de uma fruta:  maça
# Voce gosta de  alface e maça

# %%
'''
11. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela o
numero informado e na linha de baixo o dobro deste número da seguinte forma:
Numero -> X
Dobro deste numero -> Y
'''
numero_real=float(input("Digite um número real:  "))
print("Numero -> ", numero_real)
print("Dobro deste numero -> ", numero_real*2)
# Out:
# Digite um número real:  6
# Numero ->  6.0
# Dobro deste numero ->  12.0

# %%
'''
12. Reescrever o programa anterior apresentando o quadrado e o cubo do número informado
'''
numero_real=float(input("Digite um número real:  "))
print("Numero -> ", numero_real)
print("Dobro deste numero -> ", numero_real*2)
# Out:
# Digite um número real:  5
# Numero ->  5.0
# Dobro deste numero ->  10.0

# %%
'''
13. Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente
na tela a soma dos dois números informados da seguinte forma: "O numeros N e X
somados correspondem a Y"
'''
numero_inteiro1=int(input("Digite um número inteiro:  "))
numero_inteiro2=int(input("Digite um número inteiro:  "))
# Out:
# Digite um número inteiro:  6
# Digite um número inteiro:  9

# %%
'''
14. Escreva um programa que solicite ao usuário dois números reais e ao final apresente na
tela o produto dos dois números informados da seguinte forma: "O produto dos numeros N
e X corresponde a Y"
'''
numero_real1=float(input("Digite um número real:  "))
numero_real2=float(input("Digite um número real:  "))
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1*numero_real2)

# %%
'''
15. Refazer o programa 14 realizando as quatro operações aritméticas básicas
'''
numero_real1=float(input("Digite um número real:  "))
numero_real2=float(input("Digite um número real:  "))
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1*numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1+numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1-numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1/numero_real2)

# %% [markdown]
# Lista 2 - Estruturas condicionais (IF,ELif,Else)

# %%
"""1. Elabore um programa que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que 10 (dez)
"""
numero_real =float(input("informe um número real:  "))
if numero_real>10:
  print("O número informado foi:", numero_real, "é maior que 10")

# %%
'''2. Escreva um programa que solicite ao usuário um número real e ao final imprima na tela se
o número informado é maior ou igual a dez ou menor que 10 (dez)
'''
numero_real = float(input("informe um número real:  "))
if numero_real >= 10:
  print("O número informado foi:", numero_real, "que é maior ou igual a 10")
else:
  print("O número informado foi:", numero_real, "que é menor que 10")

# %%
'''3. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que dez, se é menor que dez, ou se é igual a dez
'''
numero_real2=float(iput("informe um número real:  "))
  if numero_real2>10:
    print("O número informado foi:", numero_real2, "que é maior que 10")
  elif numero_real2<10:
    print("O número informado foi:", numero_real2, "que é menor que 10")
  else:
    print("O número informado foi:", numero_real2, "que é igual a 10")

# %%
'''4. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
número informado é positivo, negativo ou nulo (zero)
'''
número_real3=float(input("informe um número real:  "))
if numero_real3>0:
  print("O número informado foi:", numero_real3, "que é positivo")
elif numero_real3<0:
  print("O número informado foi:", numero_real3, "que é negativo")
else:
  print("O número informado foi:", numero_real3, "que é nulo")l

# %%
''' Elabore um algoritmo que leia um número inteiro e imprima uma das mensagens: é múltiplo
de 3, ou, não é múltiplo de 3
'''
numero_inteiro4=int(input("informe um número inteiro:  "))
if numero_inteiro4%3==0:
  print("O número informado foi:", numero_inteiro4, "que é múltiplo de 3")
else:
  print("O número informado foi:", numero_inteiro4, "que não é múltiplo de 3")

# %%
''' 6. Refazer o exercício anterior, solicitando antes o múltiplo a ser testado
'''
numero_inteiro4=int(input("informe um número inteiro:  "))
numero_inteiro5=int(input("informe um número inteiro:  "))
if numero_inteiro4%numero_inteiro5==0:
  print("O número informado foi:", numero_inteiro4, "que é múltiplo de", numero_inteiro5)
else:
  print("O número informado foi:", numero_inteiro4, "que não é múltiplo de", numero_inteiro5)

# %%
'''7. Desenvolva um algoritmo que classifique um número inteiro fornecido pelo usuário como
par ou ímpar
'''
numero_inteiro6=int(input("informe um número inteiro:  "))
if numero_inteiro6%2==0:
  print("O número informado foi:", numero_inteiro6, "que é par")
else:
  print("O número informado foi:", numero_inteiro6, "que é ímpar")

# %%
'''8. Elabore um algoritmo que leia um número, e se ele for maior do que 20, imprimir a metade
desse número, caso contrário, imprimir o dobro do número
'''
numero_inteiro7=int(input('informe um número inteiro:'))
if numero_inteiro7>20:
  print("O número informado foi:", numero_inteiro7, "que é maior do que 20, logo sua metade é:", numero_inteiro7/2)
else:
  print("O número informado foi:", numero_inteiro7, "que é menor do que 20, logo seu dobro é:", numero_inteiro7*2)

# %%
'''9. Elabore um algoritmo que leia dois números inteiros e realize a adição; caso o resultado
seja maior que 10, imprima o quadrado do resultado, caso contrário, imprima a metade dele
'''
numero_inteiro8=int(input('informe um número inteiro:'))
numero_inteiro9=int(input('informe um número inteiro:'))
resultado=numero_inteiro8+numero_inteiro9
if resultado>10:
  print("O resultado da soma foi:", resultado, "que é maior do que 10, Logo seu quadrado é:", resultado**2)
else:
  print("O resultado da soma foi:", resultado, "que é maior do que 10, Logo sua metade é:", resultado/2)

# %%
'''10. O sistema de avaliação de determinada disciplina é composto por três provas.
 A primeira prova tem peso 2, a segunda tem peso 3 e a terceira tem peso 5. Considerando que a média para a aprovação
 é 6.0, faça um algoritimo para calcular a média final de um aluno desta disciplina e dizer se o aluno foi aprovado ou não
'''
nota1=float(input('informe a nota da primeira prova:'))
nota2=float(input('informe a nota da segunda prova:'))
nota3=float(input('informe a nota da terceira prova:'))
media=(nota1*2+nota2*3+nota3*5/10)
if media>=6:
  print("O aluno foi aprovado com média:", media)
else:
   print("O aluno foi reprovado com média:", media)

# %%
'''11. Elabore um algoritmo que leia o nome e o peso de duas pessoas e imprima o nome da
pessoa mais pesada
'''
nome1=input('informe o nome da primeira pessoa:')
peso1=float(input('informe o peso da primeira pessoa:'))
nome2=input('informe o nome da segunda pessoa:')
peso2=float(input('informe o peso da segunda pessoa:'))
if peso1>peso2:
  print("A pessoa mais pesada é:", nome1)
else:
  print("A pessoa mais pesada é:", nome2)

# %%
'''12. Elabore um algoritmo que indique se um número digitado está compreendido entre 20 e
90, ou não
'''
numero_inteiro10=int(input('informe um número inteiro:'))
if numero_inteiro10>20 and numero_inteiro10<90:
  print("O número informado está entre 20 e 90")
else:
  print("O número informado não está entre 20 e 90")

# %%
''' 13. Elabore um algoritimo que leia dois números e imprima qual é maio, qual é menor, ou se são iguias
'''
numero_inteiro11=int(input('informe um número inteiro:'))
numero_inteiro12=int(input('informe um número inteiro:'))
if numero_inteiro11>numero_inteiro12:
  print("O primeiro número é maior que o segundo")
elif numero_inteiro11<numero_inteiro12:
  print("O segundo número é maior que o primeiro")
else:
  print("Os números são iguais")

# %%
'''14. Escreva um programa em linguagem C que solicite ao usuário a média para aprovação
em um curso e em seguida solicite ao usuário o nome, sexo e as 03 notas do aluno e ao
final imprima a frase: "O aluno XXXXX foi aprovado com media YY" considerando o gênero
do(a) aluno(a) e se foi aprovado(a) ou reprovado(a)
'''
media_aprovacao=float(input('informe a média para aprovação:'))
nome=input('informe o nome do aluno:')
sexo=input('informe o sexo do aluno:')
nota1=float(input('informe a nota da primeira prova:'))
nota2=float(input('informe a nota da segunda prova:'))
nota3=float(input('informe a nota da terceira prova:'))
media=(nota1+nota2+nota3)/3
if media>=media_aprovacao and sexo=='F':
  print("A aluna", nome, "foi aprovada com média", media)
elif media>=media_aprovacao and sexo=='M':
  print("O aluno", nome, "foi aprovado com média", media)
else:
  print("O aluno", nome, "foi reprovado com média", media)

# %%
'''14. Escreva um programa em linguagem C que solicite ao usuário a média para aprovação
em um curso e em seguida solicite ao usuário o nome, sexo e as 03 notas do aluno e ao
final imprima a frase: "O aluno XXXXX foi aprovado com media YY" considerando o gênero
do(a) aluno(a) e se foi aprovado(a) ou reprovado(a)
'''
media_aprovacao=float(input('informe a média para aprovação:'))
nome=input('informe o nome do aluno:')
sexo=input('informe o sexo do aluno:')
nota1=float(input('informe a nota da primeira prova:'))
nota2=float(input('informe a nota da segunda prova:'))
nota3=float(input('informe a nota da terceira prova:'))
media=(nota1+nota2+nota3)/3
if media>=media_aprovacao and sexo=='F':
  print("A aluna", nome, "foi aprovada com média", media)
elif media>=media_aprovacao and sexo=='M':
    print("O aluno", nome, "foi aprovado com média", media)
else:
    print("O aluno", nome, "foi reprovado com média", media)

# %% [markdown]
# Lista 3

# %%
'''
1. Elabore um algoritmo que imprima na tela lado a lado o texto "Hello World!" 10 vezes
'''

print("Hello World! " * 10)

# %%
"""
2. Elabore um algoritmo que imprima na tela o texto "Hello World!" 10 vezes, um por linha.
"""

for _ in range(10):
    print("Hello World!")

# %%
"""3. Elabore um algoritmo que imprima todos os números inteiros de 1 até 100 inclusive.
"""

for i in range(1, 101):
    print(i)

# %%
"""4. Elabore um algoritmo que imprima 100 vezes o texto "1- Hello World!" com o número.
"""
for i in range(1, 101):
    print(f"{i}- Hello World!")

# %%
"""5. Elabore um algoritmo que imprima todos os números decrescentes de 100 até 0 inclusive
"""

for i in range(100, -1, -1):
    print(i)

# %%
"""6. Elabore um algoritmo que imprima todos os números pares inteiros de 1 até 1000
"""

for i in range(2, 1001, 2):
    print(i)

# %%
""""7. Elabore um algoritmo que imprima todos os números ímpares de 1000 até 0
"""

for i in range(999, -1, -2):
    print(i)

# %%
"""8. Elabore um algoritmo que imprima a soma dos 100 primeiros números inteiros positivos.
"""

soma = sum(range(1, 101))
print("Soma:", soma)

# %%
"""9. Elabore um algoritmo que solicite ao usuário um número inteiro que indicará a quantidade
"""

n = int(input("Quantas vezes imprimir 'Hello World!'? "))
for _ in range(n):
    print("Hello World!")

# %%
"""10. Elabore um algoritmo que solicite ao usuário uma palavra e um número inteiro que
"""
palavra = input("Digite uma palavra: ")
n = int(input("Quantas vezes deseja imprimir? "))
for _ in range(n):
    print(palavra)

# %%
"""11. Elabore um algoritmo que leia um número de entrada que indicará a quantidade de
números a serem lidos. Em seguida, leia n números (conforme o valor informado
anteriormente) e imprima a soma e a média aritmética dos números informados.
"""
n = int(input("Quantos números deseja inserir? "))
soma = 0
for _ in range(n):
    numero = float(input("Digite um número: "))
    soma += numero
media = soma / n if n > 0 else 0
print("Soma:", soma)
print("Média:", media)

# %%
"""12. Elabore um algoritmo que leia um número de entrada que indicará a quantidade de
registros a serem lidos (N). Em seguida algoritmo deve solicitar o nome e idade de N
pessoas e ao final apresentar o nome da pessoa mais velha
"""
n = int(input("Quantas pessoas? "))
mais_velho_nome = ""
mais_velho_idade = -1
for _ in range(n):
    nome = input("Nome: ")
    idade = int(input("Idade: "))
    if idade > mais_velho_idade:
        mais_velho_nome = nome
        mais_velho_idade = idade
print("Pessoa mais velha:", mais_velho_nome)

# %%
"""13. Elabore um algoritmo que leia um número de entrada que indicará a quantidade de
registros a serem lidos (N). Em seguida algoritmo deve solicitar o sexo (M/F) e idade de N
pessoas e ao final apresentar a média de idade de ambos os gêneros catalogados
"""

n = int(input("Quantas pessoas? "))
soma_m = soma_f = qtd_m = qtd_f = 0
for _ in range(n):
    sexo = input("Sexo (M/F): ").strip().upper()
    idade = int(input("Idade: "))
    if sexo == 'M':
        soma_m += idade
        qtd_m += 1
    elif sexo == 'F':
        soma_f += idade
        qtd_f += 1
media_m = soma_m / qtd_m if qtd_m else 0
media_f = soma_f / qtd_f if qtd_f else 0
print("Média idade Masculino:", media_m)
print("Média idade Feminino:", media_f)

# %%
"""14. Elabore um algoritmo que solicite ao usuário 10 números reais e ao final apresente o
maior e o menor deles.
"""

numeros = [float(input(f"Digite o {i+1}º número: ")) for i in range(10)]
print("Maior:", max(numeros))
print("Menor:", min(numeros))

# %%
"""15. Elabore um algoritmo que solicite N números reais e quando o usuário informar o valor
nulo 0 (zero) o programa ordene e mostre todos os números informados de forma crescente
"""
numeros = []
while True:
    num = float(input("Digite um número (0 para sair): "))
    if num == 0:
        break
    numeros.append(num)
numeros.sort()
print("Números ordenados:", numeros)

# %%
"""16. Escreva um programa que vá solicitando as idades dos alunos da sala até que todos
sejam informados (perguntar ao usuário se deseja informar a idade do próximo aluno). Ao
final apresentar a idade do mais novo, a idade do mais velho, Quantos alunos têm mais de
18 anos, quantos alunos têm até 18 anos, a média aritmética e a mediana.
"""

idades = []
while True:
    resposta = input("Deseja informar idade de um aluno? (S/N): ").strip().upper()
    if resposta != 'S':
        break
    idade = int(input("Digite a idade: "))
    idades.append(idade)

if idades:
    mais_novo = min(idades)
    mais_velho = max(idades)
    maiores_18 = sum(1 for i in idades if i > 18)
    menores_ou_18 = len(idades) - maiores_18
    media = sum(idades) / len(idades)
    idades.sort()
    meio = len(idades) // 2
    if len(idades) % 2 == 0:
        mediana = (idades[meio - 1] + idades[meio]) / 2
    else:
        mediana = idades[meio]
    print("Mais novo:", mais_novo)
    print("Mais velho:", mais_velho)
    print("Mais de 18 anos:", maiores_18)
    print("Até 18 anos:", menores_ou_18)
    print("Média:", media)
    print("Mediana:", mediana)
else:
    print("Nenhuma idade foi informada.")
